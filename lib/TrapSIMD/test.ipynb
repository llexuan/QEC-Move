# %%
from sabre_iontrap import *
from grid_iontrap import *
from qiskit import qasm3

class OpNode:
    def __init__(self, op, p0, p1):
        self.op = op
        self.p0 = p0
        self.p1 = p1

D = 5
N_list = [10]
Alg_list = ['QAOA', 'RCA', 'BV', 'VQE']
tag_list = ['a', 'b', 'c', 'd']
L = 3
CZ = 3
draw_flag = False

circ = qasm3.load(f"test.qasm")
# circ = genQiskitQAOA(20)

result_our_list, node_list = grid_compiler(D, L, CZ, circ, draw_flag)

import json
json_str = json.dumps(node_list)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sabre_iontrap import *
#       2 from grid_iontrap import *
#       3 from qiskit import qasm3
#
# File /scr/dataset/keyin/Code/QEC-Move/lib/TrapSIMD/sabre_iontrap.py:7
#       5 # from coupling_graph import *
#       6 import  matplotlib.pyplot as plt
# ----> 7 from .benchmarks.generate_benchmark import *
#       8 from qiskit.converters import circuit_to_dag
#       9 import networkx as nx
#
# ImportError: attempted relative import with no known parent package
